# %%
from kafka import KafkaConsumer
topic_name = 'items'
consumer = KafkaConsumer(topic_name)
for message in consumer:
    print(message)
# Out:
# ConsumerRecord(topic='items', partition=0, offset=2, timestamp=1700276860343, timestamp_type=0, key=None, value=b'Hello Kafka Python!!!!', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=22, serialized_header_size=-1)
# ConsumerRecord(topic='items', partition=0, offset=3, timestamp=1700276969932, timestamp_type=0, key=None, value=b'Hello Kafka Python!!!!', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=22, serialized_header_size=-1)
# ConsumerRecord(topic='items', partition=0, offset=4, timestamp=1700276969932, timestamp_type=0, key=None, value=b'Hello Kafka Python!!!!', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=22, serialized_header_size=-1)
# ConsumerRecord(topic='items', partition=0, offset=5, timestamp=1700276969932, timestamp_type=0, key=None, value=b'Hello Kafka Python!!!!', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=22, serialized_header_size=-1)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# /Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/consumer.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/consumer.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> topic_name = 'items'
# ----> <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/consumer.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> consumer = KafkaConsumer(topic_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/consumer/group.py:356, in KafkaConsumer.__init__(self, *topics, **configs)
#     352         self.config['api_version'] = tuple(map(int, str_version.split('.')))
#     353     log.warning('use api_version=%s [tuple] -- "%s" as str is deprecated',
#     354                 str(self.config['api_version']), str_version)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# /Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaTest.ipynb Cell 3 line 8
#       <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaTest.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> topic_name = 'RandomNumber'
#       <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaTest.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> kafka_server = 'localhost:9092'
# ----> <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaTest.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> producer = KafkaProducer(bootstrap_servers=kafka_server,value_serializer = lambda x:dumps(x).encode('utf-8'))
#      <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaTest.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> for e in range(1000):
# ...
