# %% [markdown]
# ## Dowload Kafka and Unzip

# %%
# !curl -sSOL https://downloads.apache.org/kafka/3.6.0/kafka_2.13-3.6.0.tgz
# !tar -xzf kafka_2.13-3.6.0.tgz

# %% [markdown]
# ## Start zookeeper server and kafka server

# %%
# !./kafka_2.13-3.6.0/bin/zookeeper-server-start.sh -daemon ./kafka_2.13-3.6.0/config/zookeeper.properties
# !./kafka_2.13-3.6.0/bin/kafka-server-start.sh -daemon ./kafka_2.13-3.6.0/config/server.properties

# %% [markdown]
# ## Create a topic

# %%
# !./kafka_2.13-3.6.0/bin/kafka-topics.sh --create --bootstrap-server 127.0.0.1:9092 --replication-factor 1 --partitions 1 --topic TestTopic
# Out:
# Created topic TestTopic.

# %% [markdown]
# ## Describe the created topic

# %%
# !./kafka_2.13-3.6.0/bin/kafka-topics.sh --describe --bootstrap-server 127.0.0.1:9092 --topic TestTopic
# Out:
# Topic: TestTopic	TopicId: h7S63OnDTWehpjstXUYGRQ	PartitionCount: 1	ReplicationFactor: 1	Configs:
# 	Topic: TestTopic	Partition: 0	Leader: 0	Replicas: 0	Isr: 0

# %% [markdown]
# ## Write some event in the topic

# %%
# !./kafka_2.13-3.6.0/bin/kafka-console-producer.sh --topic TestTopic --bootstrap-server 127.0.0.1:9092
# Out:
# >hello kafka
# >first line
# >second line
# >

# %% [markdown]
# ## Read the event

# %%
# !./kafka_2.13-3.6.0/bin/kafka-console-consumer.sh --topic TestTopic --from-beginning --bootstrap-server 127.0.0.1:9092
# Out:
# hello kafka
# first line
# second line
# Processed a total of 3 messages

# %% [markdown]
# ## Or you can run producer and consumer parallelly in different terminals

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# %xterm

# %%
# %xterm

# %% [markdown]
# ## Use kafka-python on Colab

# %%
# !pip install kafka-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from kafka import KafkaProducer

TOPIC_NAME = 'TestTopic'
KAFKA_SERVER = 'localhost:9092'

producer = KafkaProducer(bootstrap_servers = KAFKA_SERVER)
producer.send(TOPIC_NAME, b'Hello Kafka Python!!!')
producer.flush()

# %%
from kafka import KafkaConsumer

TOPIC_NAME = 'TestTopic'
KAFKA_SERVER = 'localhost:9092'

consumer = KafkaConsumer(TOPIC_NAME,
                              bootstrap_servers = KAFKA_SERVER,
                              auto_offset_reset = 'earliest')

print(consumer)
for message in consumer:
    print(message)
