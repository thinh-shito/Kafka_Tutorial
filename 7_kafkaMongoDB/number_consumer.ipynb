# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads

topic_name = "numtest"
consumer = KafkaConsumer(
						topic_name,
						bootstrap_servers=['localhost:9092'],
						auto_offset_reset = 'earliest',
						enable_auto_commit = True,
						group_id='my-group',
						value_deserializer=lambda x: loads(x.decode('utf-8'))
						)
client = MongoClient('localhost:27017')
collection = client.numtest.numtest

for message in consumer:
    message = message.value
    # print(message)
    collection.insert_one(message)
    print('{} added to {}'.format(message, collection))
# Out:
# {'number': 0, '_id': ObjectId('6558c0a2e9a5c717c7981ffd')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 1, '_id': ObjectId('6558c0a3e9a5c717c7981ffe')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 2, '_id': ObjectId('6558c0a3e9a5c717c7981fff')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 3, '_id': ObjectId('6558c0a3e9a5c717c7982000')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 4, '_id': ObjectId('6558c0a3e9a5c717c7982001')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 5, '_id': ObjectId('6558c0a3e9a5c717c7982002')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 6, '_id': ObjectId('6558c0a3e9a5c717c7982003')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 7, '_id': ObjectId('6558c0a3e9a5c717c7982004')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 8, '_id': ObjectId('6558c0a3e9a5c717c7982005')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 9, '_id': ObjectId('6558c0a3e9a5c717c7982006')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 10, '_id': ObjectId('6558c0a3e9a5c717c7982007')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 11, '_id': ObjectId('6558c0a3e9a5c717c7982008')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 12, '_id': ObjectId('6558c0a3e9a5c717c7982009')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 13, '_id': ObjectId('6558c0a3e9a5c717c798200a')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 14, '_id': ObjectId('6558c0a3e9a5c717c798200b')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 15, '_id': ObjectId('6558c0a3e9a5c717c798200c')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 16, '_id': ObjectId('6558c0a3e9a5c717c798200d')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 17, '_id': ObjectId('6558c0a3e9a5c717c798200e')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 18, '_id': ObjectId('6558c0a3e9a5c717c798200f')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 19, '_id': ObjectId('6558c0a3e9a5c717c7982010')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 20, '_id': ObjectId('6558c0a3e9a5c717c7982011')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 21, '_id': ObjectId('6558c0a3e9a5c717c7982012')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 22, '_id': ObjectId('6558c0a3e9a5c717c7982013')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 23, '_id': ObjectId('6558c0a3e9a5c717c7982014')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 24, '_id': ObjectId('6558c0a3e9a5c717c7982015')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 25, '_id': ObjectId('6558c0a3e9a5c717c7982016')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 26, '_id': ObjectId('6558c0a3e9a5c717c7982017')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 27, '_id': ObjectId('6558c0a3e9a5c717c7982018')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 28, '_id': ObjectId('6558c0a3e9a5c717c7982019')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 29, '_id': ObjectId('6558c0a3e9a5c717c798201a')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 30, '_id': ObjectId('6558c0a3e9a5c717c798201b')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 31, '_id': ObjectId('6558c0a3e9a5c717c798201c')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 32, '_id': ObjectId('6558c0a3e9a5c717c798201d')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 33, '_id': ObjectId('6558c0a3e9a5c717c798201e')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 34, '_id': ObjectId('6558c0a3e9a5c717c798201f')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 35, '_id': ObjectId('6558c0a3e9a5c717c7982020')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 36, '_id': ObjectId('6558c0a3e9a5c717c7982021')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 37, '_id': ObjectId('6558c0a3e9a5c717c7982022')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 38, '_id': ObjectId('6558c0a3e9a5c717c7982023')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 39, '_id': ObjectId('6558c0a3e9a5c717c7982024')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 40, '_id': ObjectId('6558c0a3e9a5c717c7982025')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 41, '_id': ObjectId('6558c0a3e9a5c717c7982026')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 42, '_id': ObjectId('6558c0a3e9a5c717c7982027')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 43, '_id': ObjectId('6558c0a3e9a5c717c7982028')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 44, '_id': ObjectId('6558c0a3e9a5c717c7982029')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 45, '_id': ObjectId('6558c0a3e9a5c717c798202a')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 46, '_id': ObjectId('6558c0a3e9a5c717c798202b')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 47, '_id': ObjectId('6558c0a3e9a5c717c798202c')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 48, '_id': ObjectId('6558c0a3e9a5c717c798202d')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 49, '_id': ObjectId('6558c0a3e9a5c717c798202e')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 50, '_id': ObjectId('6558c0a3e9a5c717c798202f')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 51, '_id': ObjectId('6558c0a3e9a5c717c7982030')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 52, '_id': ObjectId('6558c0a3e9a5c717c7982031')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 53, '_id': ObjectId('6558c0a3e9a5c717c7982032')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 54, '_id': ObjectId('6558c0a3e9a5c717c7982033')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number':
')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 146, '_id': ObjectId('6558c0a3e9a5c717c798208f')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 147, '_id': ObjectId('6558c0a3e9a5c717c7982090')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 148, '_id': ObjectId('6558c0a3e9a5c717c7982091')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 149, '_id': ObjectId('6558c0a3e9a5c717c7982092')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 150, '_id': ObjectId('6558c0a3e9a5c717c7982093')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 0, '_id': ObjectId('6558c0a7e9a5c717c7982094')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 1, '_id': ObjectId('6558c0ace9a5c717c7982095')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 2, '_id': ObjectId('6558c0b1e9a5c717c7982096')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 3, '_id': ObjectId('6558c0b6e9a5c717c7982097')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 4, '_id': ObjectId('6558c0bbe9a5c717c7982098')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 5, '_id': ObjectId('6558c0c0e9a5c717c7982099')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 6, '_id': ObjectId('6558c0c5e9a5c717c798209a')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 7, '_id': ObjectId('6558c0cae9a5c717c798209b')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 8, '_id': ObjectId('6558c0cfe9a5c717c798209c')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 9, '_id': ObjectId('6558c0d4e9a5c717c798209d')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 10, '_id': ObjectId('6558c0d9e9a5c717c798209e')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 11, '_id': ObjectId('6558c0dee9a5c717c798209f')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 12, '_id': ObjectId('6558c0e3e9a5c717c79820a0')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 13, '_id': ObjectId('6558c0e8e9a5c717c79820a1')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 14, '_id': ObjectId('6558c0ede9a5c717c79820a2')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 15, '_id': ObjectId('6558c0f2e9a5c717c79820a3')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 16, '_id': ObjectId('6558c0f7e9a5c717c79820a4')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 17, '_id': ObjectId('6558c0fce9a5c717c79820a5')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 18, '_id': ObjectId('6558c101e9a5c717c79820a6')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 19, '_id': ObjectId('6558c106e9a5c717c79820a7')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 20, '_id': ObjectId('6558c10be9a5c717c79820a8')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 21, '_id': ObjectId('6558c110e9a5c717c79820a9')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 22, '_id': ObjectId('6558c115e9a5c717c79820aa')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# {'number': 23, '_id': ObjectId('6558c11ae9a5c717c79820ab')} added to Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaMongoDB/number_consumer.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaMongoDB/number_consumer.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> client = MongoClient('localhost:27017')
#      <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaMongoDB/number_consumer.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> collection = client.numtest.numtest
# ---> <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaMongoDB/number_consumer.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> for message in consumer:
#      <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaMongoDB/number_consumer.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a>     message = message.value
#      <a href='vscode-notebook-cell:/Users/dothinhtpr247gmai.com/Desktop/BigData/Kafka/kafkaMongoDB/number_consumer.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a>     # print(message)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/consumer/group.py:675, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     665 def _poll_once(self, timeout_ms, max_records, update_offsets=True):
#     666     """Do one round of polling. In addition to checking for new data, this does
#     667     any needed heart-beating, auto-commits, and offset updates.
#     668
#    (...)
#     673         dict: Map of topic to list of records (may be empty).
#     674     """
# --> 675     self._coordinator.poll()
#     677     # Fetch positions if we have partitions we're subscribed to that we
#     678     # don't know the offset for
#     679     if not self._subscription.has_all_fetch_positions():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/coordinator/consumer.py:270, in ConsumerCoordinator.poll(self)
#     267     return
#     269 self._invoke_completed_offset_commit_callbacks()
# --> 270 self.ensure_coordinator_ready()
#     272 if self.config['api_version'] >= (0, 9) and self._subscription.partitions_auto_assigned():
#     273     if self.need_rejoin():
#     274         # due to a race condition between the initial metadata fetch and the
#     275         # initial rebalance, we need to ensure that the metadata is fresh
#    (...)
#     283         # essentially be ignored. See KAFKA-3949 for the complete
#     284         # description of the problem.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/coordinator/base.py:265, in BaseCoordinator.ensure_coordinator_ready(self)
#     263     log.debug('Requesting metadata for group coordinator request: %s', future.exception)
#     264     metadata_update = self._client.cluster.request_update()
# --> 265     self._client.poll(future=metadata_update)
#     266 else:
#     267     time.sleep(self.config['retry_backoff_ms'] / 1000)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:
